# %%
from keras.models import Sequential
# Out:
# Using TensorFlow backend.

# %%
from keras.layers import Dense, Dropout

from sklearn.model_selection import train_test_split

import numpy

# %%
numpy.random.seed(7)

# %%
dataset = numpy.loadtxt("pima-indians-diabetes.csv", delimiter=",")

# %%
# !ls
# Out:
# 10-9.jpg				keras-tensorflow-playground-master.zip
# Anaconda3-5.2.0-Linux-x86_64.sh		pima-indians-diabetes.csv
# diabetes.csv				Priyanka Gupta_CV_2018.docx
# flask-trump-20180718T101738Z-001.zip	sav-linux-free-9.tgz
# github-git-cheat-sheet.pdf		sublime_text_3_build_3176_x64.tar.bz2
# google-chrome-stable_current_amd64.deb	Untitled.ipynb
# important.zip				weights.h5
# keras_diabetes_test.ipynb

# %%
X = dataset[: , 0:8]

# %%
Y = dataset [ : , 8]

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
model = Sequential()

# %%
model.add(Dense(15, input_dim=8, activation='relu')) 

model.add(Dense(10, activation='relu'))

model.add(Dense(8, activation='relu'))

model.add(Dropout(.2))

model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss="binary_crossentropy", optimizer="adam", metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs = 1000, batch_size=20, validation_data=(x_test, y_test))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/1000
# 614/614 [==============================] - 1s 994us/step - loss: 5.6718 - acc: 0.4609 - val_loss: 2.1931 - val_acc: 0.6039
# Epoch 2/1000
# 614/614 [==============================] - 0s 110us/step - loss: 1.7817 - acc: 0.5977 - val_loss: 0.9723 - val_acc: 0.5519
# Epoch 3/1000
# 614/614 [==============================] - 0s 109us/step - loss: 1.1780 - acc: 0.5635 - val_loss: 0.7464 - val_acc: 0.6299
# Epoch 4/1000
# 614/614 [==============================] - 0s 103us/step - loss: 1.0223 - acc: 0.5570 - val_loss: 0.7053 - val_acc: 0.6299
# Epoch 5/1000
# 614/614 [==============================] - 0s 137us/step - loss: 0.7922 - acc: 0.6042 - val_loss: 0.6702 - val_acc: 0.6104
# Epoch 6/1000
# 614/614 [==============================] - 0s 144us/step - loss: 0.7166 - acc: 0.6417 - val_loss: 0.6597 - val_acc: 0.6429
# Epoch 7/1000
# ...

# %%
model.save('weights.h5')

# %%
prediction = model.predict(numpy.array([[7,100,0,0,0,30.0,0.484,32]]))

# %%
print(prediction)
# Out:
# [[0.22946924]]

# %%
print(1 if prediction > 0.5 else 0 )
# Out:
# 0

# %%
pred = [] 
number = 0 
for i in range(8) : 
    number = float(input())
    pred.append(number)
# Out:
# 17
# 200
# 2
# 4
# 5
# 121
# 3
# 12

# %%
pred2 = [pred]

# %%
print(pred2)
# Out:
# [[17.0, 200.0, 2.0, 4.0, 5.0, 121.0, 3.0, 12.0]]

# %%
arrpred = numpy.array(pred2)

# %%
prediction = model.predict(arrpred)

# %%
print(prediction)
# Out:
# [[0.99995434]]

# %%
print(1 if prediction > 0.5 else 0)
# Out:
# 1
